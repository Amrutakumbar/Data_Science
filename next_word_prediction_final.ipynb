# %%
#load the document

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
#save the document

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

# %%
#load the new text

# %%
# load text
raw_text = load_doc('rhyme.txt')
print(raw_text)

# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)
# Out:
# Sing a song of sixpence,
# A pocket full of rye.
# Four and twenty blackbirds,
# Baked in a pie.
#
# When the pie was opened
# The birds began to sing;
# Wasn't that a dainty dish,
# To set before the king.
#
# The king was in his counting house,
# Counting out his money;
# The queen was in the parlour,
# Eating bread and honey.
#
# The maid was in the garden,
# Hanging out the clothes,
# When down came a blackbird
# And pecked off her nose.

# %%
# organize into sequences of characters
length = 10
sequences = list()
for i in range(length, len(raw_text)):
	# select sequence of tokens
	seq = raw_text[i-length:i+1]
	# store
	sequences.append(seq)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 4777

# %%
sequences
# Out:
# ['Sing a song',
#  'ing a song\n',
#  'ng a song\ni',
#  'g a song\nin',
#  ' a song\ning',
#  'a song\ning ',
#  ' song\ning a',
#  'song\ning a ',
#  'ong\ning a s',
#  'ng\ning a so',
#  'g\ning a son',
#  '\ning a song',
#  'ing a song ',
#  'ng a song \n',
#  'g a song \nn',
#  ' a song \nng',
#  'a song \nng ',
#  ' song \nng a',
#  'song \nng a ',
#  'ong \nng a s',
#  'ng \nng a so',
#  'g \nng a son',
#  ' \nng a song',
#  '\nng a song ',
#  'ng a song o',
#  'g a song o\n',
#  ' a song o\ng',
#  'a song o\ng ',
#  ' song o\ng a',
#  'song o\ng a ',
#  'ong o\ng a s',
#  'ng o\ng a so',
#  'g o\ng a son',
#  ' o\ng a song',
#  'o\ng a song ',
#  '\ng a song o',
#  'g a song of',
#  ' a song of\n',
#  'a song of\n ',
#  ' song of\n a',
#  'song of\n a ',
#  'ong of\n a s',
#  'ng of\n a so',
#  'g of\n a son',
#  ' of\n a song',
#  'of\n a song ',
#  'f\n a song o',
#  '\n a song of',
#  ' a song of ',
#  'a song of \n',
#  ' song of \na',
#  'song of \na ',
#  'ong of \na s',
#  'ng of \na so',
#  'g of \na son',
#  ' of \na song',
#  'of \na song ',
#  'f \na song o',
#  ' \na song of',
#  '\na song of ',
#  'a song of s',
#  ' song of s\n',
#  'song of s\n ',
#  'ong of s\n s',
#  'ng of s\n so',
#  'g of s\n son',
#  ' of s\n song',
#  'of s\n song ',
#  'f s\n song o',
#  ' s\n song of',
#  's\n song of ',
#  '\n song of s',
#  ' song of si',
#  'song of si\n',
#  'ong of si\ns',
#  'ng of si\nso',
#  'g of si\nson',
#  ' of si\nsong',
#  'of si\nsong ',
#  'f si\nsong o',
#  ' si\nsong of',
#  'si\nsong of ',
#  'i\nsong of s',
#  '\nsong of si',
#  'song of six',
#  'ong of six\n',
#  'ng of six\no',
#  'g of six\non',
#  ' of six\nong',
#  'of six\nong ',
#  'f six\nong o',
#  ' six\nong of',
#  'six\nong of ',
#  'ix\nong of s',
#  'x\nong of si',
#  '\nong of six',
#  'ong of sixp',
#  'ng of sixp\n',
#  'g of sixp\nn',
#  ' of sixp\nng',
#  'of sixp\nng ',
#  'f sixp\nng o',
#  ' sixp\nng of',
#  'sixp\nng of ',
#  'ixp\nng of s',
#  'xp\nng of si',
#  'p\nng of six',
#  '\nng of sixp',
#  'ng of sixpe',
#  'g of sixpe\n',
#  ' of sixpe\ng',
#  'of sixpe\ng ',
#  'f sixpe\ng o',
#  ' sixpe\ng of',
#  'sixpe\ng of ',
#  'ixpe\ng of s',
#  'xpe\ng of si',
#  'pe\ng of six',
#  'e\ng of sixp',
#  '\ng of sixpe',
#  'g of sixpen',
#  ' of sixpen\n',
#  'of sixpen\n ',
#  'f sixpen\n o',
#  ' sixpen\n of',
#  'sixpen\n of ',
#  'ixpen\n of s',
#  'xpen\n of si',
#  'pen\n of six',
#  'en\n of sixp',
#  'n\n of sixpe',
#  '\n of sixpen',
#  ' of sixpenc',
#  'of sixpenc\n',
#  'f sixpenc\no',
#  ' sixpenc\nof',
#  'sixpenc\nof ',
#  'ixpenc\nof s',
#  'xpenc\nof si',
#  'penc\nof six',
#  'enc\nof sixp',
#  'nc\nof sixpe',
#  'c\nof sixpen',
#  '\nof sixpenc',
#  'of sixpence',
#  'f sixpence\n',
#  ' sixpence\nf',
#  'sixpence\nf ',
#  'ixpence\nf s',
#  'xpence\nf si',
#  'pence\nf six',
#  'ence\nf sixp',
#  'nce\nf sixpe',
#  'ce\nf sixpen',
#  'e\nf sixpenc',
#  '\nf sixpence',
#  'f sixpence,',
#  ' sixpence,\n',
#  'sixpence,\n ',
#  'ixpence,\n s',
#  'xpence,\n si',
#  'pence,\n six',
#  'ence,\n sixp',
#  'nce,\n sixpe',
#  'ce,\n sixpen',
#  'e,\n sixpenc',
#  ',\n sixpence',
#  '\n sixpence,',
#  ' sixpence, ',
#  'sixpence, \n',
#  'ixpence, \ns',
#  'xpence, \nsi',
#  'pence, \nsix',
#  'ence, \nsixp',
#  'nce, \nsixpe',
#  'ce, \nsixpen',
#  'e, \nsixpenc',
#  ', \nsixpence',
#  ' \nsixpence,',
#  '\nsixpence, ',
#  'sixpence, A',
#  'ixpence, A\n',
#  'xpence, A\ni',
#  'pence, A\nix',
#  'ence, A\nixp',
#  'nce, A\nixpe',
#  'ce, A\nixpen',
#  'e, A\nixpenc',
#  ', A\nixpence',
#  ' A\nixpence,',
#  'A\nixpence, ',
#  '\nixpence, A',
#  'ixpence, A ',
#  'xpence, A \n',
#  'pence, A \nx',
#  'ence, A \nxp',
#  'nce, A \nxpe',
#  'ce, A \nxpen',
#  'e, A \nxpenc',
#  ', A \nxpence',
#  ' A \nxpence,',
#  'A \nxpence, ',
#  ' \nxpence, A',
#  '\nxpence, A ',
#  'xpence, A p',
#  'pence, A p\n',
#  'ence, A p\np',
#  'nce, A p\npe',
#  'ce, A p\npen',
#  'e, A p\npenc',
#  ', A p\npence',
#  ' A p\npence,',
#  'A p\npence, ',
#  ' p\npence, A',
#  'p\npence, A ',
#  '\npence, A p',
#  'pence, A po',
#  'ence, A po\n',
#  'nce, A po\ne',
#  'ce, A po\nen',
#  'e, A po\nenc',
#  ', A po\nence',
#  ' A po\nence,',
#  'A po\nence, ',
#  ' po\nence, A',
#  'po\nence, A ',
#  'o\nence, A p',
#  '\nence, A po',
#  'ence, A poc',
#  'nce, A poc\n',
#  'ce, A poc\nn',
#  'e, A poc\nnc',
#  ', A poc\nnce',
#  ' A poc\nnce,',
#  'A poc\nnce, ',
#  ' poc\nnce, A',
#  'poc\nnce, A ',
#  'oc\nnce, A p',
#  'c\nnce, A po',
#  '\nnce, A poc',
#  'nce, A pock',
#  'ce, A pock\n',
#  'e, A pock\nc',
#  ', A pock\nce',
#  ' A pock\nce,',
#  'A pock\nce, ',
#  ' pock\nce, A',
#  'pock\nce, A ',
#  'ock\nce, A p',
#  'ck\nce, A po',
#  'k\nce, A poc',
#  '\nce, A pock',
#  'ce, A pocke',
#  'e, A pocke\n',
#  ', A pocke\ne',
#  ' A pocke\ne,',
#  'A pocke\ne, ',
#  ' pocke\ne, A',
#  'pocke\ne, A ',
#  'ocke\ne, A p',
#  'cke\ne, A po',
#  'ke\ne, A poc',
#  'e\ne, A pock',
#  '\ne, A pocke',
#  'e, A pocket',
#  ', A pocket\n',
#  ' A pocket\n,',
#  'A pocket\n, ',
#  ' pocket\n, A',
#  'pocket\n, A ',
#  'ocket\n, A p',
#  'cket\n, A po',
#  'ket\n, A poc',
#  'et\n, A pock',
#  't\n, A pocke',
#  '\n, A pocket',
#  ', A pocket ',
#  ' A pocket \n',
#  'A pocket \n ',
#  ' pocket \n A',
#  'pocket \n A ',
#  'ocket \n A p',
#  'cket \n A po',
#  'ket \n A poc',
#  'et \n A pock',
#  't \n A pocke',
#  ' \n A pocket',
#  '\n A pocket ',
#  ' A pocket f',
#  'A pocket f\n',
#  ' pocket f\nA',
#  'pocket f\nA ',
#  'ocket f\nA p',
#  'cket f\nA po',
#  'ket f\nA poc',
#  'et f\nA pock',
#  't f\nA pocke',
#  ' f\nA pocket',
#  'f\nA pocket ',
#  '\nA pocket f',
#  'A pocket fu',
#  ' pocket fu\n',
#  'pocket fu\n ',
#  'ocket fu\n p',
#  'cket fu\n po',
#  'ket fu\n poc',
#  'et fu\n pock',
#  't fu\n pocke',
#  ' fu\n pocket',
#  'fu\n pocket ',
#  'u\n pocket f',
#  '\n pocket fu',
#  ' pocket ful',
#  'pocket ful\n',
#  'ocket ful\np',
#  'cket ful\npo',
#  'ket ful\npoc',
#  'et ful\npock',
#  't ful\npocke',
#  ' ful\npocket',
#  'ful\npocket ',
#  'ul\npocket f',
#  'l\npocket fu',
#  '\npocket ful',
#  'pocket full',
#  'ocket full\n',
#  'cket full\no',
#  'ket full\noc',
#  'et full\nock',
#  't full\nocke',
#  ' full\nocket',
#  'full\nocket ',
#  'ull\nocket f',
#  'll\nocket fu',
#  'l\nocket ful',
#  '\nocket full',
#  'ocket full ',
#  'cket full \n',
#  'ket full \nc',
#  'et full \nck',
#  't full \ncke',
#  ' full \ncket',
#  'full \ncket ',
#  'ull \ncket f',
#  'll \ncket fu',
#  'l \ncket ful',
#  ' \ncket full',
#  '\ncket full ',
#  'cket full o',
#  'ket full o\n',
#  'et full o\nk',
#  't full o\nke',
#  ' full o\nket',
#  'full o\nket ',
#  'ull o\nket f',
#  'll o\nket fu',
#  'l o\nket ful',
#  ' o\nket full',
#  'o\nket full ',
#  '\nket full o',
#  'ket full of',
#  'et full of\n',
#  't full of\ne',
#  ' full of\net',
#  'full of\net ',
#  'ull of\net f',
#  'll of\net fu',
#  'l of\net ful',
#  ' of\net full',
#  'of\net full ',
#  'f\net full o',
#  '\net full of',
#  'et full of ',
#  't full of \n',
#  ' full of \nt',
#  'full of \nt ',
#  'ull of \nt f',
#  'll of \nt fu',
#  'l of \nt ful',
#  ' of \nt full',
#  'of \nt full ',
#  'f \nt full o',
#  ' \nt full of',
#  '\nt full of ',
#  't full of r',
#  ' full of r\n',
#  'full of r\n ',
#  'ull of r\n f',
#  'll of r\n fu',
#  'l of r\n ful',
#  ' of r\n full',
#  'of r\n full ',
#  'f r\n full o',
#  ' r\n full of',
#  'r\n full of ',
#  '\n full of r',
#  ' full of ry',
#  'full of ry\n',
#  'ull of ry\nf',
#  'll of ry\nfu',
#  'l of ry\nful',
#  ' of ry\nfull',
#  'of ry\nfull ',
#  'f ry\nfull o',
#  ' ry\nfull of',
#  'ry\nfull of ',
#  'y\nfull of r',
#  '\nfull of ry',
#  'full of rye',
#  'ull of rye\n',
#  'll of rye\nu',
#  'l of rye\nul',
#  ' of rye\null',
#  'of rye\null ',
#  'f rye\null o',
#  ' rye\null of',
#  'rye\null of ',
#  'ye\null of r',
#  'e\null of ry',
#  '\null of rye',
#  'ull of rye.',
#  'll of rye.\n',
#  'l of rye.\nl',
#  ' of rye.\nll',
#  'of rye.\nll ',
#  'f rye.\nll o',
#  ' rye.\nll of',
#  'rye.\nll of ',
#  'ye.\nll of r',
#  'e.\nll of ry',
#  '.\nll of rye',
#  '\nll of rye.',
#  'll of rye. ',
#  'l of rye. \n',
#  ' of rye. \nl',
#  'of rye. \nl ',
#  'f rye. \nl o',
#  ' rye. \nl of',
#  'rye. \nl of ',
#  'ye. \nl of r',
#  'e. \nl of ry',
#  '. \nl of rye',
#  ' \nl of rye.',
#  '\nl of rye. ',
#  'l of rye. F',
#  ' of rye. F\n',
#  'of rye. F\n ',
#  'f rye. F\n o',
#  ' rye. F\n of',
#  'rye. F\n of ',
#  'ye. F\n of r',
#  'e. F\n of ry',
#  '. F\n of rye',
#  ' F\n of rye.',
#  'F\n of rye. ',
#  '\n of rye. F',
#  ' of rye. Fo',
#  'of rye. Fo\n',
#  'f rye. Fo\no',
#  ' rye. Fo\nof',
#  'rye. Fo\nof ',
#  'ye. Fo\nof r',
#  'e. Fo\nof ry',
#  '. Fo\nof rye',
#  ' Fo\nof rye.',
#  'Fo\nof rye. ',
#  'o\nof rye. F',
#  '\nof rye. Fo',
#  'of rye. Fou',
#  'f rye. Fou\n',
#  ' rye. Fou\nf',
#  'rye. Fou\nf ',
#  'ye. Fou\nf r',
#  'e. Fou\nf ry',
#  '. Fou\nf rye',
#  ' Fou\nf rye.',
#  'Fou\nf rye. ',
#  'ou\nf rye. F',
#  'u\nf rye. Fo',
#  '\nf rye. Fou',
#  'f rye. Four',
#  ' rye. Four\n',
#  'rye. Four\n ',
#  'ye. Four\n r',
#  'e. Four\n ry',
#  '. Four\n rye',
#  ' Four\n rye.',
#  'Four\n rye. ',
#  'our\n rye. F',
#  'ur\n rye. Fo',
#  'r\n rye. Fou',
#  '\n rye. Four',
#  ' rye. Four ',
#  'rye. Four \n',
#  'ye. Four \nr',
#  'e. Four \nry',
#  '. Four \nrye',
#  ' Four \nrye.',
#  'Four \nrye. ',
#  'our \nrye. F',
#  'ur \nrye. Fo',
#  'r \nrye. Fou',
#  ' \nrye. Four',
#  '\nrye. Four ',
#  'rye. Four a',
#  'ye. Four a\n',
#  'e. Four a\ny',
#  '. Four a\nye',
#  ' Four a\nye.',
#  'Four a\nye. ',
#  'our a\nye. F',
#  'ur a\nye. Fo',
#  'r a\nye. Fou',
#  ' a\nye. Four',
#  'a\nye. Four ',
#  '\nye. Four a',
#  'ye. Four an',
#  'e. Four an\n',
#  '. Four an\ne',
#  ' Four an\ne.',
#  'Four an\ne. ',
#  'our an\ne. F',
#  'ur an\ne. Fo',
#  'r an\ne. Fou',
#  ' an\ne. Four',
#  'an\ne. Four ',
#  'n\ne. Four a',
#  '\ne. Four an',
#  'e. Four and',
#  '. Four and\n',
#  ' Four and\n.',
#  'Four and\n. ',
#  'our and\n. F',
#  'ur and\n. Fo',
#  'r and\n. Fou',
#  ' and\n. Four',
#  'and\n. Four ',
#  'nd\n. Four a',
#  'd\n. Four an',
#  '\n. Four and',
#  '. Four and ',
#  ' Four and \n',
#  'Four and \n ',
#  'our and \n F',
#  'ur and \n Fo',
#  'r and \n Fou',
#  ' and \n Four',
#  'and \n Four ',
#  'nd \n Four a',
#  'd \n Four an',
#  ' \n Four and',
#  '\n Four and ',
#  ' Four and t',
#  'Four and t\n',
#  'our and t\nF',
#  'ur and t\nFo',
#  'r and t\nFou',
#  ' and t\nFour',
#  'and t\nFour ',
#  'nd t\nFour a',
#  'd t\nFour an',
#  ' t\nFour and',
#  't\nFour and ',
#  '\nFour and t',
#  'Four and tw',
#  'our and tw\n',
#  'ur and tw\no',
#  'r and tw\nou',
#  ' and tw\nour',
#  'and tw\nour ',
#  'nd tw\nour a',
#  'd tw\nour an',
#  ' tw\nour and',
#  'tw\nour and ',
#  'w\nour and t',
#  '\nour and tw',
#  'our and twe',
#  'ur and twe\n',
#  'r and twe\nu',
#  ' and twe\nur',
#  'and twe\nur ',
#  'nd twe\nur a',
#  'd twe\nur an',
#  ' twe\nur and',
#  'twe\nur and ',
#  'we\nur and t',
#  'e\nur and tw',
#  '\nur and twe',
#  'ur and twen',
#  'r and twen\n',
#  ' and twen\nr',
#  'and twen\nr ',
#  'nd twen\nr a',
#  'd twen\nr an',
#  ' twen\nr and',
#  'twen\nr and ',
#  'wen\nr and t',
#  'en\nr and tw',
#  'n\nr and twe',
#  '\nr and twen',
#  'r and twent',
#  ' and twent\n',
#  'and twent\n ',
#  'nd twent\n a',
#  'd twent\n an',
#  ' twent\n and',
#  'twent\n and ',
#  'went\n and t',
#  'ent\n and tw',
#  'nt\n and twe',
#  't\n and twen',
#  '\n and twent',
#  ' and twenty',
#  'and twenty\n',
#  'nd twenty\na',
#  'd twenty\nan',
#  ' twenty\nand',
#  'twenty\nand ',
#  'wenty\nand t',
#  'enty\nand tw',
#  'nty\nand twe',
#  'ty\nand twen',
#  'y\nand twent',
#  '\nand twenty',
#  'and twenty ',
#  'nd twenty \n',
#  'd twenty \nn',
#  ' twenty \nnd',
#  'twenty \nnd ',
#  'wenty \nnd t',
#  'enty \nnd tw',
#  'nty \nnd twe',
#  'ty \nnd twen',
#  'y \nnd twent',
#  ' \nnd twenty',
#  '\nnd twenty ',
#  'nd twenty b',
#  'd twenty b\n',
#  ' twenty b\nd',
#  'twenty b\nd ',
#  'wenty b\nd t',
#  'enty b\nd tw',
#  'nty b\nd twe',
#  'ty b\nd twen',
#  'y b\nd twent',
#  ' b\nd twenty',
#  'b\nd twenty ',
#  '\nd twenty b',
#  'd twenty bl',
#  ' twenty bl\n',
#  'twenty bl\n ',
#  'wenty bl\n t',
#  'enty bl\n tw',
#  'nty bl\n twe',
#  'ty bl\n twen',
#  'y bl\n twent',
#  ' bl\n twenty',
#  'bl\n twenty ',
#  'l\n twenty b',
#  '\n twenty bl',
#  ' twenty bla',
#  'twenty bla\n',
#  'wenty bla\nt',
#  'enty bla\ntw',
#  'nty bla\ntwe',
#  'ty bla\ntwen',
#  'y bla\ntwent',
#  ' bla\ntwenty',
#  'bla\ntwenty ',
#  'la\ntwenty b',
#  'a\ntwenty bl',
#  '\ntwenty bla',
#  'twenty blac',
#  'wenty blac\n',
#  'enty blac\nw',
#  'nty blac\nwe',
#  'ty blac\nwen',
#  'y blac\nwent',
#  ' blac\nwenty',
#  'blac\nwenty ',
#  'lac\nwenty b',
#  'ac\nwenty bl',
#  'c\nwenty bla',
#  '\nwenty blac',
#  'wenty black',
#  'enty black\n',
#  'nty black\ne',
#  'ty black\nen',
#  'y black\nent',
#  ' black\nenty',
#  'black\nenty ',
#  'lack\nenty b',
#  'ack\nenty bl',
#  'ck\nenty bla',
#  'k\nenty blac',
#  '\nenty black',
#  'enty blackb',
#  'nty blackb\n',
#  'ty blackb\nn',
#  'y blackb\nnt',
#  ' blackb\nnty',
#  'blackb\nnty ',
#  'lackb\nnty b',
#  'ackb\nnty bl',
#  'ckb\nnty bla',
#  'kb\nnty blac',
#  'b\nnty black',
#  '\nnty blackb',
#  'nty blackbi',
#  'ty blackbi\n',
#  'y blackbi\nt',
#  ' blackbi\nty',
#  'blackbi\nty ',
#  'lackbi\nty b',
#  'ackbi\nty bl',
#  'ckbi\nty bla',
#  'kbi\nty blac',
#  'bi\nty black',
#  'i\nty blackb',
#  '\nty blackbi',
#  'ty blackbir',
#  'y blackbir\n',
#  ' blackbir\ny',
#  'blackbir\ny ',
#  'lackbir\ny b',
#  'ackbir\ny bl',
#  'ckbir\ny bla',
#  'kbir\ny blac',
#  'bir\ny black',
#  'ir\ny blackb',
#  'r\ny blackbi',
#  '\ny blackbir',
#  'y blackbird',
#  ' blackbird\n',
#  'blackbird\n ',
#  'lackbird\n b',
#  'ackbird\n bl',
#  'ckbird\n bla',
#  'kbird\n blac',
#  'bird\n black',
#  'ird\n blackb',
#  'rd\n blackbi',
#  'd\n blackbir',
#  '\n blackbird',
#  ' blackbirds',
#  'blackbirds\n',
#  'lackbirds\nb',
#  'ackbirds\nbl',
#  'ckbirds\nbla',
#  'kbirds\nblac',
#  'birds\nblack',
#  'irds\nblackb',
#  'rds\nblackbi',
#  'ds\nblackbir',
#  's\nblackbird',
#  '\nblackbirds',
#  'blackbirds,',
#  'lackbirds,\n',
#  'ackbirds,\nl',
#  'ckbirds,\nla',
#  'kbirds,\nlac',
#  'birds,\nlack',
#  'irds,\nlackb',
#  'rds,\nlackbi',
#  'ds,\nlackbir',
#  's,\nlackbird',
#  ',\nlackbirds',
#  '\nlackbirds,',
#  'lackbirds, ',
#  'ackbirds, \n',
#  'ckbirds, \na',
#  'kbirds, \nac',
#  'birds, \nack',
#  'irds, \nackb',
#  'rds, \nackbi',
#  'ds, \nackbir',
#  's, \nackbird',
#  ', \nackbirds',
#  ' \nackbirds,',
#  '\nackbirds, ',
#  'ackbirds, B',
#  'ckbirds, B\n',
#  'kbirds, B\nc',
#  'birds, B\nck',
#  'irds, B\nckb',
#  'rds, B\nckbi',
#  'ds, B\nckbir',
#  's, B\nckbird',
#  ', B\nckbirds',
#  ' B\nckbirds,',
#  'B\nckbirds, ',
#  '\nckbirds, B',
#  'ckbirds, Ba',
#  'kbirds, Ba\n',
#  'birds, Ba\nk',
#  'irds, Ba\nkb',
#  'rds, Ba\nkbi',
#  'ds, Ba\nkbir',
#  's, Ba\nkbird',
#  ', Ba\nkbirds',
#  ' Ba\nkbirds,',
#  'Ba\nkbirds, ',
#  'a\nkbirds, B',
#  '\nkbirds, Ba',
#  'kbirds, Bak',
#  'birds, Bak\n',
#  'irds, Bak\nb',
#  'rds, Bak\nbi',
#  'ds, Bak\nbir',
#  's, Bak\nbird',
#  ', Bak\nbirds',
#  ' Bak\nbirds,',
#  'Bak\nbirds, ',
#  'ak\nbirds, B',
#  'k\nbirds, Ba',
#  '\nbirds, Bak',
#  'birds, Bake',
#  'irds, Bake\n',
#  'rds, Bake\ni',
#  'ds, Bake\nir',
#  's, Bake\nird',
#  ', Bake\nirds',
#  ' Bake\nirds,',
#  'Bake\nirds, ',
#  'ake\nirds, B',
#  'ke\nirds, Ba',
#  'e\nirds, Bak',
#  '\nirds, Bake',
#  'irds, Baked',
#  'rds, Baked\n',
#  'ds, Baked\nr',
#  's, Baked\nrd',
#  ', Baked\nrds',
#  ' Baked\nrds,',
#  'Baked\nrds, ',
#  'aked\nrds, B',
#  'ked\nrds, Ba',
#  'ed\nrds, Bak',
#  'd\nrds, Bake',
#  '\nrds, Baked',
#  'rds, Baked ',
#  'ds, Baked \n',
#  's, Baked \nd',
#  ', Baked \nds',
#  ' Baked \nds,',
#  'Baked \nds, ',
#  'aked \nds, B',
#  'ked \nds, Ba',
#  'ed \nds, Bak',
#  'd \nds, Bake',
#  ' \nds, Baked',
#  '\nds, Baked ',
#  'ds, Baked i',
#  's, Baked i\n',
#  ', Baked i\ns',
#  ' Baked i\ns,',
#  'Baked i\ns, ',
#  'aked i\ns, B',
#  'ked i\ns, Ba',
#  'ed i\ns, Bak',
#  'd i\ns, Bake',
#  ' i\ns, Baked',
#  'i\ns, Baked ',
#  '\ns, Baked i',
#  's, Baked in',
#  ', Baked in\n',
#  ' Baked in\n,',
#  'Baked in\n, ',
#  'aked in\n, B',
#  'ked in\n, Ba',
#  'ed in\n, Bak',
#  'd in\n, Bake',
#  ' in\n, Baked',
#  'in\n, Baked ',
#  'n\n, Baked i',
#  '\n, Baked in',
#  ', Baked in ',
#  ' Baked in \n',
#  'Baked in \n ',
#  'aked in \n B',
#  'ked in \n Ba',
#  'ed in \n Bak',
#  'd in \n Bake',
#  ' in \n Baked',
#  'in \n Baked ',
#  'n \n Baked i',
#  ' \n Baked in',
#  '\n Baked in ',
#  ' Baked in a',
#  'Baked in a\n',
#  'aked in a\nB',
#  'ked in a\nBa',
#  'ed in a\nBak',
#  'd in a\nBake',
#  ' in a\nBaked',
#  'in a\nBaked ',
#  'n a\nBaked i',
#  ' a\nBaked in',
#  'a\nBaked in ',
#  '\nBaked in a',
#  'Baked in a ',
#  'aked in a \n',
#  'ked in a \na',
#  'ed in a \nak',
#  'd in a \nake',
#  ' in a \naked',
#  'in a \naked ',
#  'n a \naked i',
#  ' a \naked in',
#  'a \naked in ',
#  ' \naked in a',
#  '\naked in a ',
#  'aked in a p',
#  'ked in a p\n',
#  'ed in a p\nk',
#  'd in a p\nke',
#  ' in a p\nked',
#  'in a p\nked ',
#  'n a p\nked i',
#  ' a p\nked in',
#  'a p\nked in ',
#  ' p\nked in a',
#  'p\nked in a ',
#  '\nked in a p',
#  'ked in a pi',
#  'ed in a pi\n',
#  'd in a pi\ne',
#  ' in a pi\ned',
#  'in a pi\ned ',
#  'n a pi\ned i',
#  ' a pi\ned in',
#  'a pi\ned in ',
#  ' pi\ned in a',
#  'pi\ned in a ',
#  'i\ned in a p',
#  '\ned in a pi',
#  'ed in a pie',
#  'd in a pie\n',
#  ' in a pie\nd',
#  'in a pie\nd ',
#  'n a pie\nd i',
#  ' a pie\nd in',
#  'a pie\nd in ',
#  ' pie\nd in a',
#  'pie\nd in a ',
#  'ie\nd in a p',
#  'e\nd in a pi',
#  '\nd in a pie',
#  'd in a pie.',
#  ' in a pie.\n',
#  'in a pie.\n ',
#  'n a pie.\n i',
#  ' a pie.\n in',
#  'a pie.\n in ',
#  ' pie.\n in a',
#  'pie.\n in a ',
#  'ie.\n in a p',
#  'e.\n in a pi',
#  '.\n in a pie',
#  '\n in a pie.',
#  ' in a pie. ',
#  'in a pie. \n',
#  'n a pie. \ni',
#  ' a pie. \nin',
#  'a pie. \nin ',
#  ' pie. \nin a',
#  'pie. \nin a ',
#  'ie. \nin a p',
#  'e. \nin a pi',
#  '. \nin a pie',
#  ' \nin a pie.',
#  '\nin a pie. ',
#  'in a pie. W',
#  'n a pie. W\n',
#  ' a pie. W\nn',
#  'a pie. W\nn ',
#  ' pie. W\nn a',
#  'pie. W\nn a ',
#  'ie. W\nn a p',
#  'e. W\nn a pi',
#  '. W\nn a pie',
#  ' W\nn a pie.',
#  'W\nn a pie. ',
#  '\nn a pie. W',
#  'n a pie. Wh',
#  ' a pie. Wh\n',
#  'a pie. Wh\n ',
#  ' pie. Wh\n a',
#  'pie. Wh\n a ',
#  'ie. Wh\n a p',
#  'e. Wh\n a pi',
#  '. Wh\n a pie',
#  ' Wh\n a pie.',
#  'Wh\n a pie. ',
#  'h\n a pie. W',
#  '\n a pie. Wh',
#  ' a pie. Whe',
#  'a pie. Whe\n',
#  ' pie. Whe\na',
#  'pie. Whe\na ',
#  ...]

# %%
# save sequences to file
out_filename = 'char_sequences.txt'
save_doc(sequences, out_filename)

# %%
#APPLY NN

# %%
from numpy import array
from pickle import dump
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load
in_filename = 'char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')

# %%
# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
print(chars)
mapping = dict((c, i) for i, c in enumerate(chars))
print(mapping)
sequences = list()
for line in lines:
	# integer encode line
	encoded_seq = [mapping[char] for char in line]
	# store
	sequences.append(encoded_seq)

# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# ['\n', ' ', "'", ',', '.', ';', 'A', 'B', 'C', 'E', 'F', 'H', 'S', 'T', 'W', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't', 'u', 'w', 'x', 'y']
# {'\n': 0, ' ': 1, "'": 2, ',': 3, '.': 4, ';': 5, 'A': 6, 'B': 7, 'C': 8, 'E': 9, 'F': 10, 'H': 11, 'S': 12, 'T': 13, 'W': 14, 'a': 15, 'b': 16, 'c': 17, 'd': 18, 'e': 19, 'f': 20, 'g': 21, 'h': 22, 'i': 23, 'k': 24, 'l': 25, 'm': 26, 'n': 27, 'o': 28, 'p': 29, 'q': 30, 'r': 31, 's': 32, 't': 33, 'u': 34, 'w': 35, 'x': 36, 'y': 37}
# Vocabulary Size: 38

# %%
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)

# %%
# define model
model = Sequential()
model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 75)                34200
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 13/13 - 3s - loss: 3.6266 - accuracy: 0.0351
# Epoch 2/100
# 13/13 - 0s - loss: 3.5312 - accuracy: 0.1554
# Epoch 3/100
# 13/13 - 0s - loss: 3.2465 - accuracy: 0.1905
# Epoch 4/100
# 13/13 - 0s - loss: 3.0907 - accuracy: 0.1905
# Epoch 5/100
# 13/13 - 0s - loss: 3.0236 - accuracy: 0.1905
# Epoch 6/100
# 13/13 - 0s - loss: 2.9992 - accuracy: 0.1905
# Epoch 7/100
# 13/13 - 0s - loss: 2.9882 - accuracy: 0.1905
# Epoch 8/100
# 13/13 - 0s - loss: 2.9697 - accuracy: 0.1905
# Epoch 9/100
# 13/13 - 0s - loss: 2.9536 - accuracy: 0.1905
# Epoch 10/100
# 13/13 - 0s - loss: 2.9433 - accuracy: 0.1905
# Epoch 11/100
# 13/13 - 0s - loss: 2.9199 - accuracy: 0.1905
# Epoch 12/100
# 13/13 - 0s - loss: 2.9000 - accuracy: 0.1930
# Epoch 13/100
# 13/13 - 0s - loss: 2.8768 - accuracy: 0.2281
# Epoch 14/100
# 13/13 - 0s - loss: 2.8395 - accuracy: 0.2005
# Epoch 15/100
# 13/13 - 0s - loss: 2.8086 - accuracy: 0.2356
# Epoch 16/100
# 13/13 - 0s - loss: 2.7723 - accuracy: 0.2180
# Epoch 17/100
# 13/13 - 0s - loss: 2.7457 - accuracy: 0.2431
# Epoch 18/100
# 13/13 - 0s - loss: 2.6972 - accuracy: 0.2481
# Epoch 19/100
# 13/13 - 0s - loss: 2.6658 - accuracy: 0.2707
# Epoch 20/100
# 13/13 - 0s - loss: 2.6044 - accuracy: 0.2932
# Epoch 21/100
# 13/13 - 0s - loss: 2.5663 - accuracy: 0.2857
# Epoch 22/100
# 13/13 - 0s - loss: 2.5317 - accuracy: 0.3158
# Epoch 23/100
# 13/13 - 0s - loss: 2.4864 - accuracy: 0.3008
# Epoch 24/100
# 13/13 - 0s - loss: 2.4242 - accuracy: 0.3333
# Epoch 25/100
# 13/13 - 0s - loss: 2.3769 - accuracy: 0.3434
# Epoch 26/100
# 13/13 - 0s - loss: 2.3461 - accuracy: 0.3534
# Epoch 27/100
# 13/13 - 0s - loss: 2.2878 - accuracy: 0.3534
# Epoch 28/100
# 13/13 - 0s - loss: 2.2396 - accuracy: 0.3759
# Epoch 29/100
# 13/13 - 0s - loss: 2.1929 - accuracy: 0.4010
# Epoch 30/100
# 13/13 - 0s - loss: 2.1374 - accuracy: 0.3985
# Epoch 31/100
# 13/13 - 0s - loss: 2.1070 - accuracy: 0.4035
# Epoch 32/100
# 13/13 - 0s - loss: 2.0628 - accuracy: 0.4160
# Epoch 33/100
# 13/13 - 0s - loss: 2.0266 - accuracy: 0.4160
# Epoch 34/100
# 13/13 - 0s - loss: 1.9722 - accuracy: 0.4511
# Epoch 35/100
# 13/13 - 0s - loss: 1.9291 - accuracy: 0.4561
# Epoch 36/100
# 13/13 - 0s - loss: 1.8872 - accuracy: 0.4737
# Epoch 37/100
# 13/13 - 0s - loss: 1.8386 - accuracy: 0.4887
# Epoch 38/100
# 13/13 - 0s - loss: 1.8133 - accuracy: 0.4912
# Epoch 39/100
# 13/13 - 0s - loss: 1.7631 - accuracy: 0.5113
# Epoch 40/100
# 13/13 - 0s - loss: 1.7127 - accuracy: 0.5063
# Epoch 41/100
# 13/13 - 0s - loss: 1.7079 - accuracy: 0.5163
# Epoch 42/100
# 13/13 - 0s - loss: 1.6289 - accuracy: 0.5564
# Epoch 43/100
# 13/13 - 0s - loss: 1.6020 - accuracy: 0.5764
# Epoch 44/100
# 13/13 - 0s - loss: 1.5461 - accuracy: 0.5915
# Epoch 45/100
# 13/13 - 0s - loss: 1.5343 - accuracy: 0.5815
# Epoch 46/100
# 13/13 - 0s - loss: 1.4900 - accuracy: 0.5815
# Epoch 47/100
# 13/13 - 0s - loss: 1.4281 - accuracy: 0.6416
# Epoch 48/100
# 13/13 - 0s - loss: 1.4164 - accuracy: 0.6241
# Epoch 49/100
# 13/13 - 0s - loss: 1.3614 - accuracy: 0.6516
# Epoch 50/100
# 13/13 - 0s - loss: 1.3279 - accuracy: 0.6591
# Epoch 51/100
# 13/13 - 0s - loss: 1.2882 - accuracy: 0.6617
# Epoch 52/100
# 13/13 - 0s - loss: 1.2262 - accuracy: 0.6967
# Epoch 53/100
# 13/13 - 0s - loss: 1.1956 - accuracy: 0.7068
# Epoch 54/100
# 13/13 - 0s - loss: 1.1600 - accuracy: 0.7318
# Epoch 55/100
# 13/13 - 0s - loss: 1.1185 - accuracy: 0.7293
# Epoch 56/100
# 13/13 - 0s - loss: 1.0672 - accuracy: 0.7594
# Epoch 57/100
# 13/13 - 0s - loss: 1.0628 - accuracy: 0.7594
# Epoch 58/100
# 13/13 - 0s - loss: 1.0237 - accuracy: 0.7619
# Epoch 59/100
# 13/13 - 0s - loss: 0.9871 - accuracy: 0.7920
# Epoch 60/100
# 13/13 - 0s - loss: 0.9322 - accuracy: 0.8296
# Epoch 61/100
# 13/13 - 0s - loss: 0.8867 - accuracy: 0.8446
# Epoch 62/100
# 13/13 - 0s - loss: 0.8587 - accuracy: 0.8396
# Epoch 63/100
# 13/13 - 0s - loss: 0.8344 - accuracy: 0.8396
# Epoch 64/100
# 13/13 - 0s - loss: 0.8117 - accuracy: 0.8571
# Epoch 65/100
# 13/13 - 0s - loss: 0.7741 - accuracy: 0.8772
# Epoch 66/100
# 13/13 - 0s - loss: 0.7635 - accuracy: 0.8622
# Epoch 67/100
# 13/13 - 0s - loss: 0.7193 - accuracy: 0.8872
# Epoch 68/100
# 13/13 - 0s - loss: 0.6770 - accuracy: 0.9123
# Epoch 69/100
# 13/13 - 0s - loss: 0.6574 - accuracy: 0.8997
# Epoch 70/100
# 13/13 - 0s - loss: 0.6615 - accuracy: 0.9073
# Epoch 71/100
# 13/13 - 0s - loss: 0.6267 - accuracy: 0.9148
# Epoch 72/100
# 13/13 - 0s - loss: 0.5935 - accuracy: 0.9223
# Epoch 73/100
# 13/13 - 0s - loss: 0.5754 - accuracy: 0.9223
# Epoch 74/100
# 13/13 - 0s - loss: 0.5723 - accuracy: 0.9198
# Epoch 75/100
# 13/13 - 0s - loss: 0.5389 - accuracy: 0.9449
# Epoch 76/100
# 13/13 - 0s - loss: 0.5027 - accuracy: 0.9424
# Epoch 77/100
# 13/13 - 0s - loss: 0.4816 - accuracy: 0.9599
# Epoch 78/100
# 13/13 - 0s - loss: 0.4671 - accuracy: 0.9449
# Epoch 79/100
# 13/13 - 0s - loss: 0.4475 - accuracy: 0.9599
# Epoch 80/100
# 13/13 - 0s - loss: 0.4373 - accuracy: 0.9549
# Epoch 81/100
# 13/13 - 0s - loss: 0.4095 - accuracy: 0.9699
# Epoch 82/100
# 13/13 - 0s - loss: 0.3858 - accuracy: 0.9699
# Epoch 83/100
# 13/13 - 0s - loss: 0.3763 - accuracy: 0.9774
# Epoch 84/100
# 13/13 - 0s - loss: 0.3547 - accuracy: 0.9774
# Epoch 85/100
# 13/13 - 0s - loss: 0.3372 - accuracy: 0.9825
# Epoch 86/100
# 13/13 - 0s - loss: 0.3283 - accuracy: 0.9850
# Epoch 87/100
# 13/13 - 0s - loss: 0.3221 - accuracy: 0.9825
# Epoch 88/100
# 13/13 - 0s - loss: 0.3102 - accuracy: 0.9799
# Epoch 89/100
# 13/13 - 0s - loss: 0.2960 - accuracy: 0.9875
# Epoch 90/100
# 13/13 - 0s - loss: 0.2939 - accuracy: 0.9875
# Epoch 91/100
# 13/13 - 0s - loss: 0.2755 - accuracy: 0.9850
# Epoch 92/100
# 13/13 - 0s - loss: 0.2640 - accuracy: 0.9850
# Epoch 93/100
# 13/13 - 0s - loss: 0.2544 - accuracy: 0.9875
# Epoch 94/100
# 13/13 - 0s - loss: 0.2456 - accuracy: 0.9925
# Epoch 95/100
# 13/13 - 0s - loss: 0.2420 - accuracy: 0.9875
# Epoch 96/100
# 13/13 - 0s - loss: 0.2325 - accuracy: 0.9925
# Epoch 97/100
# 13/13 - 0s - loss: 0.2230 - accuracy: 0.9925
# Epoch 98/100
# 13/13 - 0s - loss: 0.2146 - accuracy: 0.9925
# Epoch 99/100
# 13/13 - 0s - loss: 0.2048 - accuracy: 0.9950
# Epoch 100/100
# 13/13 - 0s - loss: 0.2102 - accuracy: 0.9875

# %%
#save and dump the file

# %%
# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))

# %%
#to check eveything apply on test data

# %%
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
	in_text = seed_text
	# generate a fixed number of characters
	for _ in range(n_chars):
		# encode the characters as integers
		encoded = [mapping[char] for char in in_text]
		# truncate sequences to a fixed length
		encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
		# one hot encode
		encoded = to_categorical(encoded, num_classes=len(mapping))
		# predict character
		yhat = model.predict_classes(encoded, verbose=0)
		# reverse map integer to character
		out_char = ''
		for char, index in mapping.items():
			if index == yhat:
				out_char = char
				break
		# append to input
		in_text += char
	return in_text

# load the model
model = load_model('model.h5')
# load the mapping
mapping = load(open('mapping.pkl', 'rb'))

# %%
# test start of rhyme
print(generate_seq(model, mapping, 10, 'eating ', 20))
# test mid-line
print(generate_seq(model, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello worl', 20))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# eating Th hd ione. The tied
# king was in his counting house
# hello worl, The kir. was an ti
